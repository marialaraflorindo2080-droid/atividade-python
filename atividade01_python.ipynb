# %% [markdown]
# <a href="https://colab.research.google.com/github/marialaraflorindo2080-droid/atividade-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ola, mundo!")
# Out:
# ola, mundo!

# %%
print("Curso de Técnico em informática")
# Out:
# Curso de Técnico em informática

# %%
disciplina = input("Digite o nome da disciplina:")
# Out:
# Digite o nome da disciplina:ed. fisica

# %%
conteudo = input("Digite o conteudo estudado:")
# Out:
# Digite o conteudo estudado:futebol

# %%
atividade = input("Digite o número da atividade:")
# Out:
# Digite o número da atividade:01

# %%
print("\n--- Informaçoes da atividade ---")
# Out:
# --- Informaçoes da atividade ---

# %%
print("Disciplina:", disciplina)
# Out:
# Disciplina: ed. fisica

# %%
print("Conteudo:", conteudo)
# Out:
# Conteudo: futebol

# %%
print("Atividade:", atividade)
# Out:
# Atividade: 01
