# %% [markdown]
# <a href="https://colab.research.google.com/github/marialaraflorindo2080-droid/atividade-python/blob/main/atividade02_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 =10

# %%
numero2 =20

# %%
soma=numero1 + numero2
print("resultado:",soma)
# Out:
# resultado: 30
